# %%
# !pip install yfinance textstat vaderSentiment pdfplumber requests beautifulsoup4
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.12/dist-packages (0.2.66)
# Collecting textstat
#   Downloading textstat-0.7.13-py3-none-any.whl.metadata (15 kB)
# Collecting vaderSentiment
#   Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl.metadata (572 bytes)
# Collecting pdfplumber
#   Downloading pdfplumber-0.11.10-py3-none-any.whl.metadata (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 1.5 MB/s eta 0:00:00
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (4.13.5)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.0.2)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance) (0.0.13)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (4.10.0)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.12/dist-packages (from yfinance) (4.1.0)
# Requirement already satisfied: curl_cffi>=0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance) (0.15.0)
# Requirement already satisfied: protobuf>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (5.29.6)
# Requirement already satisfied: websockets>=13.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (15.0.1)
# Collecting pyphen (from textstat)
#   Downloading pyphen-0.17.2-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (from textstat) (3.9.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from textstat) (75.2.0)
# Collecting pdfminer.six==20260107 (from pdfplumber)
#   Downloading pdfminer_six-20260107-py3-none-any.whl.metadata (4.3 kB)
# Collecting Pillow>=12.2.0 (from pdfplumber)
#   Downloading pillow-12.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (9.1 kB)
# Collecting pypdfium2>=5.9.0 (from pdfplumber)
#   Downloading pypdfium2-5.11.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.0/71.0 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer.six==20260107->pdfplumber) (3.4.7)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.12/dist-packages (from pdfminer.six==20260107->pdfplumber) (49.0.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2026.6.17)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (2.8.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4) (4.15.0)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance) (13.9.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->yfinance) (2026.2)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk->textstat) (8.4.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk->textstat) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk->textstat) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk->textstat) (4.67.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=2.0.0->curl_cffi>=0.7->yfinance) (3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->curl_cffi>=0.7->yfinance) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->curl_cffi>=0.7->yfinance) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->curl_cffi>=0.7->yfinance) (0.1.2)
# Downloading textstat-0.7.13-py3-none-any.whl (177 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.1/177.1 kB 5.7 MB/s eta 0:00:00
# Downloading vaderSentiment-3.3.2-py2.py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.0/126.0 kB 5.4 MB/s eta 0:00:00
# Downloading pdfplumber-0.11.10-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 1.2 MB/s eta 0:00:00
# Downloading pdfminer_six-20260107-py3-none-any.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 33.1 MB/s eta 0:00:00
# Downloading pillow-12.3.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 48.3 MB/s eta 0:00:00
# Downloading pypdfium2-5.11.0-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 33.3 MB/s eta 0:00:00
# Downloading pyphen-0.17.2-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 24.8 MB/s eta 0:00:00
# Installing collected packages: pyphen, pypdfium2, Pillow, vaderSentiment, textstat, pdfminer.six, pdfplumber
#   Attempting uninstall: Pillow
#     Found existing installation: pillow 11.3.0
#     Uninstalling pillow-11.3.0:
#       Successfully uninstalled pillow-11.3.0
# Successfully installed Pillow-12.3.0 pdfminer.six-20260107 pdfplumber-0.11.10 pypdfium2-5.11.0 pyphen-0.17.2 textstat-0.7.13 vaderSentiment-3.3.2

# %%
import requests
import pdfplumber
import pandas as pd
import numpy as np
import re
import io
import time
import yfinance as yf
from datetime import datetime, timedelta
from textstat import flesch_kincaid_grade
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
fomc_dates = [
    # 2011 - Bernanke
    "20110427", "20110622", "20110921", "20111102",
    # 2012
    "20120125", "20120425", "20120620", "20120912", "20121212",
    # 2013
    "20130320", "20130619", "20130918", "20131218",
    # 2014 - Yellen
    "20140319", "20140618", "20140917", "20141217",
    # 2015
    "20150318", "20150617", "20150917", "20151216",
    # 2016
    "20160316", "20160615", "20160921", "20161214",
    # 2017
    "20170315", "20170614", "20170920", "20171213",
    # 2018 - Powell
    "20180321", "20180613", "20180926", "20181219",
    # 2019
    "20190130", "20190320", "20190501", "20190619", "20190731",
    "20190918", "20191030", "20191211",
    # 2020
    "20200129", "20200303", "20200315", "20200429", "20200610",
    "20200729", "20200916", "20201105", "20201216",
    # 2021
    "20210127", "20210317", "20210428", "20210616",
    "20210728", "20210922", "20211103", "20211215",
    # 2022
    "20220126", "20220316", "20220504", "20220615",
    "20220727", "20220921", "20221102", "20221214",
    # 2023
    "20230201", "20230322", "20230503", "20230614",
    "20230726", "20230920", "20231101", "20231213",
    # 2024
    "20240131", "20240320", "20240501", "20240612",
    "20240731", "20240918", "20241107", "20241218",
    # 2025
    "20250129", "20250319", "20250507", "20250618",
    "20250730", "20250917", "20251029", "20251210",
    # 2026
    "20260128", "20260318",
]

print(f"Total press conferences: {len(fomc_dates)}")
# Out:
# Total press conferences: 92

# %%
def download_transcript(date_str):
    urls_to_try = [
        f"https://www.federalreserve.gov/mediacenter/files/FOMCpresconf{date_str}.pdf",
        f"https://www.federalreserve.gov/mediacenter/files/fomcpresconf{date_str}.pdf",
    ]

    for url in urls_to_try:
        try:
            response = requests.get(url, timeout=30)
            if response.status_code == 200:
                pdf_file = io.BytesIO(response.content)
                text = ""
                with pdfplumber.open(pdf_file) as pdf:
                    for page in pdf.pages:
                        page_text = page.extract_text()
                        if page_text:
                            text += page_text + "\n"
                print(f"  ✓ {date_str} - {len(text)} chars")
                return text
        except:
            continue

    print(f"  ✗ {date_str} - FAILED")
    return None

transcripts = {}
for date_str in fomc_dates:
    transcripts[date_str] = download_transcript(date_str)
    #time.sleep(1)

successful = sum(1 for v in transcripts.values() if v is not None)
print(f"\nGot {successful}/{len(fomc_dates)} transcripts")
# Out:
#   ✓ 20110427 - 52401 chars
#   ✓ 20110622 - 43627 chars
#   ✗ 20110921 - FAILED
#   ✓ 20111102 - 44602 chars
#   ✓ 20120125 - 60374 chars
#   ✓ 20120425 - 45785 chars
#   ✓ 20120620 - 42983 chars
#   ✗ 20120912 - FAILED
#   ✓ 20121212 - 68860 chars
#   ✓ 20130320 - 52562 chars
#   ✓ 20130619 - 55717 chars
#   ✓ 20130918 - 54053 chars
#   ✓ 20131218 - 62568 chars
#   ✓ 20140319 - 46021 chars
#   ✓ 20140618 - 42104 chars
#   ✓ 20140917 - 44082 chars
#   ✓ 20141217 - 45407 chars
#   ✓ 20150318 - 42377 chars
#   ✓ 20150617 - 44882 chars
#   ✓ 20150917 - 45449 chars
#   ✓ 20151216 - 52245 chars
#   ✓ 20160316 - 45734 chars
#   ✓ 20160615 - 41670 chars
#   ✓ 20160921 - 48475 chars
#   ✓ 20161214 - 39249 chars
#   ✓ 20170315 - 40949 chars
#   ✓ 20170614 - 45481 chars
#   ✓ 20170920 - 50383 chars
#   ✓ 20171213 - 52863 chars
#   ✓ 20180321 - 42523 chars
#   ✓ 20180613 - 51844 chars
#   ✓ 20180926 - 57371 chars
#   ✓ 20181219 - 43077 chars
#   ✓ 20190130 - 46173 chars
#   ✓ 20190320 - 43705 chars
#   ✓ 20190501 - 39000 chars
#   ✓ 20190619 - 42294 chars
#   ✓ 20190731 - 44326 chars
#   ✓ 20190918 - 50954 chars
#   ✓ 20191030 - 46475 chars
#   ✓ 20191211 - 52038 chars
#   ✓ 20200129 - 54774 chars
#   ✓ 20200303 - 13649 chars
#   ✓ 20200315 - 41668 chars
#   ✓ 20200429 - 45675 chars
#   ✓ 20200610 - 58534 chars
#   ✓ 20200729 - 56874 chars
#   ✓ 20200916 - 62926 chars
#   ✓ 20201105 - 48310 chars
#   ✓ 20201216 - 59083 chars
#   ✓ 20210127 - 54119 chars
#   ✓ 20210317 - 59249 chars
#   ✓ 20210428 - 56388 chars
#   ✓ 20210616 - 59904 chars
#   ✓ 20210728 - 54977 chars
#   ✓ 20210922 - 53085 chars
#   ✓ 20211103 - 55598 chars
#   ✓ 20211215 - 61331 chars
#   ✓ 20220126 - 54740 chars
#   ✓ 20220316 - 51769 chars
#   ✓ 20220504 - 46641 chars
#   ✓ 20220615 - 54449 chars
#   ✓ 20220727 - 55415 chars
#   ✓ 20220921 - 41494 chars
#   ✓ 20221102 - 44908 chars
#   ✓ 20221214 - 45029 chars
#   ✓ 20230201 - 45052 chars
#   ✓ 20230322 - 44611 chars
#   ✓ 20230503 - 49880 chars
#   ✓ 20230614 - 50611 chars
#   ✓ 20230726 - 53393 chars
#   ✓ 20230920 - 55642 chars
#   ✓ 20231101 - 52591 chars
#   ✓ 20231213 - 45627 chars
#   ✓ 20240131 - 52807 chars
#   ✓ 20240320 - 46643 chars
#   ✓ 20240501 - 49550 chars
#   ✓ 20240612 - 53936 chars
#   ✓ 20240731 - 48534 chars
#   ✓ 20240918 - 49920 chars
#   ✓ 20241107 - 43073 chars
#   ✓ 20241218 - 55258 chars
#   ✓ 20250129 - 51774 chars
#   ✓ 20250319 - 53114 chars
#   ✓ 20250507 - 48704 chars
#   ✓ 20250618 - 54308 chars
#   ✓ 20250730 - 45761 chars
#   ✓ 20250917 - 51172 chars
#   ✓ 20251029 - 54201 chars
#   ✓ 20251210 - 51796 chars
#   ✓ 20260128 - 45531 chars
#   ✓ 20260318 - 49008 chars
#
# Got 90/92 transcripts

# %%
def split_transcript(text):
    if text is None:
        return None, None

    split_patterns = [
        r"(?i)i('d| would) be happy to take your questions",
        r"(?i)i('ll| will) now take your questions",
        r"(?i)i look forward to your questions",
        r"(?i)let me now take your questions",
        r"(?i)happy to take questions",
        r"(?i)take your questions",
    ]

    for pattern in split_patterns:
        match = re.search(pattern, text)
        if match:
            prepared = text[:match.end()].strip()
            qa = text[match.end():].strip()
            return prepared, qa

    reporter_match = re.search(r'\n[A-Z]{2,}\s[A-Z]{2,}\.?\s', text[500:])
    if reporter_match:
        split_point = 500 + reporter_match.start()
        return text[:split_point].strip(), text[split_point:].strip()

    return text, ""

split_data = {}
for date_str, text in transcripts.items():
    if text:
        prepared, qa = split_transcript(text)
        split_data[date_str] = {"prepared": prepared, "qa": qa}
        prep_pct = round(100 * len(prepared) / (len(prepared) + len(qa))) if qa else 100
        print(f"{date_str}: Prepared={prep_pct}% | Q&A={100-prep_pct}%")

print(f"\nSplit {len(split_data)} transcripts")
# Out:
# 20110427: Prepared=1% | Q&A=99%
# 20110622: Prepared=1% | Q&A=99%
# 20111102: Prepared=20% | Q&A=80%
# 20120125: Prepared=1% | Q&A=99%
# 20120425: Prepared=10% | Q&A=90%
# 20120620: Prepared=12% | Q&A=88%
# 20121212: Prepared=18% | Q&A=82%
# 20130320: Prepared=16% | Q&A=84%
# 20130619: Prepared=21% | Q&A=79%
# 20130918: Prepared=25% | Q&A=75%
# 20131218: Prepared=18% | Q&A=82%
# 20140319: Prepared=24% | Q&A=76%
# 20140618: Prepared=23% | Q&A=77%
# 20140917: Prepared=33% | Q&A=67%
# 20141217: Prepared=23% | Q&A=77%
# 20150318: Prepared=23% | Q&A=77%
# 20150617: Prepared=22% | Q&A=78%
# 20150917: Prepared=26% | Q&A=74%
# 20151216: Prepared=27% | Q&A=73%
# 20160316: Prepared=26% | Q&A=74%
# 20160615: Prepared=24% | Q&A=76%
# 20160921: Prepared=19% | Q&A=81%
# 20161214: Prepared=18% | Q&A=82%
# 20170315: Prepared=18% | Q&A=82%
# 20170614: Prepared=25% | Q&A=75%
# 20170920: Prepared=19% | Q&A=81%
# 20171213: Prepared=16% | Q&A=84%
# 20180321: Prepared=15% | Q&A=85%
# 20180613: Prepared=19% | Q&A=81%
# 20180926: Prepared=12% | Q&A=88%
# 20181219: Prepared=21% | Q&A=79%
# 20190130: Prepared=21% | Q&A=79%
# 20190320: Prepared=18% | Q&A=82%
# 20190501: Prepared=17% | Q&A=83%
# 20190619: Prepared=18% | Q&A=82%
# 20190731: Prepared=12% | Q&A=88%
# 20190918: Prepared=16% | Q&A=84%
# 20191030: Prepared=14% | Q&A=86%
# 20191211: Prepared=14% | Q&A=86%
# 20200129: Prepared=12% | Q&A=88%
# 20200303: Prepared=19% | Q&A=81%
# 20200315: Prepared=20% | Q&A=80%
# 20200429: Prepared=16% | Q&A=84%
# 20200610: Prepared=19% | Q&A=81%
# 20200729: Prepared=17% | Q&A=83%
# 20200916: Prepared=17% | Q&A=83%
# 20201105: Prepared=20% | Q&A=80%
# 20201216: Prepared=19% | Q&A=81%
# 20210127: Prepared=15% | Q&A=85%
# 20210317: Prepared=15% | Q&A=85%
# 20210428: Prepared=11% | Q&A=89%
# 20210616: Prepared=15% | Q&A=85%
# 20210728: Prepared=14% | Q&A=86%
# 20210922: Prepared=16% | Q&A=84%
# 20211103: Prepared=14% | Q&A=86%
# 20211215: Prepared=13% | Q&A=87%
# 20220126: Prepared=14% | Q&A=86%
# 20220316: Prepared=14% | Q&A=86%
# 20220504: Prepared=16% | Q&A=84%
# 20220615: Prepared=17% | Q&A=83%
# 20220727: Prepared=12% | Q&A=88%
# 20220921: Prepared=19% | Q&A=81%
# 20221102: Prepared=15% | Q&A=85%
# 20221214: Prepared=19% | Q&A=81%
# 20230201: Prepared=15% | Q&A=85%
# 20230322: Prepared=19% | Q&A=81%
# 20230503: Prepared=14% | Q&A=86%
# 20230614: Prepared=17% | Q&A=83%
# 20230726: Prepared=11% | Q&A=89%
# 20230920: Prepared=14% | Q&A=86%
# 20231101: Prepared=14% | Q&A=86%
# 20231213: Prepared=19% | Q&A=81%
# 20240131: Prepared=12% | Q&A=88%
# 20240320: Prepared=17% | Q&A=83%
# 20240501: Prepared=15% | Q&A=85%
# 20240612: Prepared=15% | Q&A=85%
# 20240731: Prepared=13% | Q&A=87%
# 20240918: Prepared=15% | Q&A=85%
# 20241107: Prepared=13% | Q&A=87%
# 20241218: Prepared=12% | Q&A=88%
# 20250129: Prepared=11% | Q&A=89%
# 20250319: Prepared=15% | Q&A=85%
# 20250507: Prepared=14% | Q&A=86%
# 20250618: Prepared=15% | Q&A=85%
# 20250730: Prepared=12% | Q&A=88%
# 20250917: Prepared=13% | Q&A=87%
# 20251029: Prepared=14% | Q&A=86%
# 20251210: Prepared=18% | Q&A=82%
# 20260128: Prepared=10% | Q&A=90%
# 20260318: Prepared=11% | Q&A=89%
#
# Split 90 transcripts

# %%
analyzer = SentimentIntensityAnalyzer()

# Define word lists
cautious_words = ["may", "might", "could", "possibly", "perhaps", "uncertain",
                  "somewhat", "broadly", "roughly", "approximately", "monitor",
                  "watching", "depends", "evaluate", "assess", "gradual"]

definitive_words = ["will", "committed", "confident", "clearly", "strongly",
                    "determined", "certain", "absolutely", "must", "decisive",
                    "without question", "no doubt"]

jargon_words = ["quantitative", "tightening", "easing", "disinflationary",
                "transitory", "forward guidance", "dot plot", "neutral rate",
                "terminal rate", "balance sheet", "tapering", "basis points",
                "dovish", "hawkish", "yield curve", "liquidity", "repo",
                "overnight", "federal funds"]

def count_words(text, word_list):
    text_lower = text.lower()
    count = 0
    for word in word_list:
        count += len(re.findall(r'\b' + word + r'\b', text_lower))
    return count

def avg_sentence_length(text):
    sentences = re.split(r'[.!?]+', text)
    sentences = [s.strip() for s in sentences if len(s.strip()) > 5]
    if not sentences:
        return 0
    return np.mean([len(s.split()) for s in sentences])

def compute_features(date_str, data):
    full = data["prepared"] + " " + data["qa"]
    prepared = data["prepared"]
    qa = data["qa"]

    # Word counts
    total_words = len(full.split())
    cautious_count = count_words(full, cautious_words)
    definitive_count = count_words(full, definitive_words)
    jargon_count = count_words(full, jargon_words)

    # Ratios
    cautious_ratio = cautious_count / max(definitive_count, 1)
    jargon_freq = jargon_count / max(total_words, 1) * 1000  # per 1000 words

    # Readability
    fk_grade = flesch_kincaid_grade(full)
    sent_length = avg_sentence_length(full)

    # Sentiment (VADER)
    prep_sentiment = analyzer.polarity_scores(prepared)["compound"]
    qa_sentiment = analyzer.polarity_scores(qa)["compound"]
    tone_shift = prep_sentiment - qa_sentiment

    return {
        "date": datetime.strptime(date_str, "%Y%m%d").strftime("%Y-%m-%d"),
        "fk_grade": round(fk_grade, 2),
        "avg_sentence_length": round(sent_length, 2),
        "total_words": total_words,
        "cautious_count": cautious_count,
        "definitive_count": definitive_count,
        "cautious_ratio": round(cautious_ratio, 3),
        "jargon_count": jargon_count,
        "jargon_freq": round(jargon_freq, 3),
        "prepared_sentiment": round(prep_sentiment, 4),
        "qa_sentiment": round(qa_sentiment, 4),
        "tone_shift": round(tone_shift, 4),
    }

# Compute for all transcripts
rows = []
for date_str, data in split_data.items():
    rows.append(compute_features(date_str, data))

linguistic_df = pd.DataFrame(rows)
linguistic_df = linguistic_df.sort_values("date").reset_index(drop=True)
print(linguistic_df.head(10))
print(f"\n{len(linguistic_df)} rows")
# Out:
#          date  fk_grade  avg_sentence_length  total_words  cautious_count  \
# 0  2011-04-27     11.60                18.57         8681              35
# 1  2011-06-22     10.94                18.11         7306              51
# 2  2011-11-02     11.48                17.87         7402              33
# 3  2012-01-25     13.78                23.56        10066              53
# 4  2012-04-25     11.55                18.93         7644              45
# 5  2012-06-20     10.85                17.61         7239              51
# 6  2012-12-12     12.25                20.77        11611              75
# 7  2013-03-20     10.43                17.21         8906              56
# 8  2013-06-19     11.07                19.01         9414              46
# 9  2013-09-18     12.06                20.35         9014              54
#
#    definitive_count  cautious_ratio  jargon_count  jargon_freq  \
# 0                60           0.583            28        3.225
# 1                31           1.645             7        0.958
# 2                44           0.750             8        1.081
# 3                53           1.000            23        2.285
# 4                35           1.286            28        3.663
# 5                24           2.125            10        1.381
# 6                81           0.926            39        3.359
# 7                40           1.400            28        3.144
# 8                48           0.958            32        3.399
# 9                54           1.000            43        4.770
#
#    prepared_sentiment  qa_sentiment  tone_shift
# 0              0.8860        1.0000     -0.1140
# 1              0.8360        0.9999     -0.1639
# 2              0.9929        0.9999     -0.0070
# 3              0.8360        1.0000     -0.1640
# 4              0.9465        0.9999     -0.0534
# 5              0.9579        0.9999     -0.0420
# 6              0.9954        1.0000     -0.0046
# 7              0.9985        0.9998     -0.0013
# 8              0.9996        1.0000     -0.0004
# 9              0.9988        1.0000     -0.0012
#
# 90 rows

# %%
# Get S&P 500 and VIX daily data
sp500 = yf.download("^GSPC", start="2011-01-01", end="2026-04-01")
vix = yf.download("^VIX", start="2011-01-01", end="2026-04-01")

# Flatten column names if multi-level
if isinstance(sp500.columns, pd.MultiIndex):
    sp500.columns = sp500.columns.get_level_values(0)
if isinstance(vix.columns, pd.MultiIndex):
    vix.columns = vix.columns.get_level_values(0)

# Reset index so date is a column
sp500 = sp500.reset_index()
vix = vix.reset_index()

# Build market features for each press conference date
market_rows = []
for date_str in linguistic_df["date"]:
    dt = pd.Timestamp(date_str)

    # Find the matching trading day (press conference day)
    sp_day = sp500[sp500["Date"] == dt]
    vix_day = vix[vix["Date"] == dt]

    # Find next trading day
    future = sp500[sp500["Date"] > dt].head(1)

    if sp_day.empty or future.empty:
        print(f"  ✗ {date_str} - no market data")
        market_rows.append({"date": date_str})
        continue

    # Same-day return (open to close captures intraday reaction)
    same_day_open = sp_day["Open"].values[0]
    same_day_close = sp_day["Close"].values[0]
    same_day_return = (same_day_close - same_day_open) / same_day_open * 100
    same_day_abs = abs(same_day_return)

    # Next-day return
    next_day_open = future["Open"].values[0]
    next_day_close = future["Close"].values[0]
    next_day_return = (next_day_close - next_day_open) / next_day_open * 100

    # Reversal: did the next day move in the opposite direction?
    reversal = 1 if (same_day_return * next_day_return < 0) else 0

    # VIX
    vix_close = vix_day["Close"].values[0] if not vix_day.empty else np.nan

    market_rows.append({
        "date": date_str,
        "sp500_same_day_return": round(same_day_return, 4),
        "sp500_same_day_abs": round(same_day_abs, 4),
        "sp500_next_day_return": round(next_day_return, 4),
        "reversal": reversal,
        "vix_close": round(vix_close, 2) if not np.isnan(vix_close) else np.nan,
    })
    print(f"  ✓ {date_str} | Return: {same_day_return:.2f}% | Reversal: {'Yes' if reversal else 'No'}")

market_df = pd.DataFrame(market_rows)
print(f"\n{len(market_df)} rows")
# Out:
# /tmp/ipykernel_1917/1360889173.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   sp500 = yf.download("^GSPC", start="2011-01-01", end="2026-04-01")
# [*********************100%***********************]  1 of 1 completed
# /tmp/ipykernel_1917/1360889173.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   vix = yf.download("^VIX", start="2011-01-01", end="2026-04-01")
# [*********************100%***********************]  1 of 1 completed
#   ✓ 2011-04-27 | Return: 0.54% | Reversal: No
#   ✓ 2011-06-22 | Return: -0.64% | Reversal: No
#   ✓ 2011-11-02 | Return: 1.50% | Reversal: No
#   ✓ 2012-01-25 | Return: 0.89% | Reversal: Yes
#   ✓ 2012-04-25 | Return: 1.35% | Reversal: No
#   ✓ 2012-06-20 | Return: -0.17% | Reversal: No
#   ✓ 2012-12-12 | Return: 0.04% | Reversal: Yes
#   ✓ 2013-03-20 | Return: 0.67% | Reversal: Yes
#   ✓ 2013-06-19 | Return: -1.39% | Reversal: No
#   ✓ 2013-09-18 | Return: 1.16% | Reversal: Yes
#   ✓ 2013-12-18 | Return: 1.64% | Reversal: No
#   ✓ 2014-03-19 | Return: -0.61% | Reversal: Yes
#   ✓ 2014-06-18 | Return: 0.73% | Reversal: No
#   ✓ 2014-09-17 | Return: 0.11% | Reversal: No
#   ✓ 2014-12-17 | Return: 1.98% | Reversal: No
#   ✓ 2015-03-18 | Return: 1.29% | Reversal: Yes
#   ✓ 2015-06-17 | Return: 0.14% | Reversal: No
#   ✓ 2015-09-17 | Return: -0.26% | Reversal: No
#   ✓ 2015-12-16 | Return: 1.30% | Reversal: Yes
#   ✓ 2016-03-16 | Return: 0.64% | Reversal: No
#   ✓ 2016-06-15 | Return: -0.29% | Reversal: Yes
#   ✓ 2016-09-21 | Return: 0.86% | Reversal: No
#   ✓ 2016-12-14 | Return: -0.66% | Reversal: Yes
#   ✓ 2017-03-15 | Return: 0.63% | Reversal: Yes
#   ✓ 2017-06-14 | Return: -0.24% | Reversal: Yes
#   ✓ 2017-09-20 | Return: 0.06% | Reversal: Yes
#   ✓ 2017-12-13 | Return: -0.18% | Reversal: No
#   ✓ 2018-03-21 | Return: -0.11% | Reversal: No
#   ✓ 2018-06-13 | Return: -0.44% | Reversal: No
#   ✓ 2018-09-26 | Return: -0.38% | Reversal: Yes
#   ✓ 2018-12-19 | Return: -1.57% | Reversal: No
#   ✓ 2019-01-30 | Return: 1.03% | Reversal: No
#   ✓ 2019-03-20 | Return: -0.25% | Reversal: Yes
#   ✓ 2019-05-01 | Return: -0.97% | Reversal: No
#   ✓ 2019-06-19 | Return: 0.20% | Reversal: No
#   ✓ 2019-07-31 | Return: -1.19% | Reversal: No
#   ✓ 2019-09-18 | Return: 0.17% | Reversal: Yes
#   ✓ 2019-10-30 | Return: 0.23% | Reversal: Yes
#   ✓ 2019-12-11 | Return: 0.19% | Reversal: No
#   ✓ 2020-01-29 | Return: -0.49% | Reversal: Yes
#   ✓ 2020-03-03 | Return: -3.01% | Reversal: Yes
#   ✗ 2020-03-15 - no market data
#   ✓ 2020-04-29 | Return: 0.72% | Reversal: Yes
#   ✓ 2020-06-10 | Return: -0.72% | Reversal: No
#   ✓ 2020-07-29 | Return: 0.97% | Reversal: No
#   ✓ 2020-09-16 | Return: -0.75% | Reversal: Yes
#   ✓ 2020-11-05 | Return: 0.71% | Reversal: No
#   ✓ 2020-12-16 | Return: 0.13% | Reversal: No
#   ✓ 2021-01-27 | Return: -2.24% | Reversal: Yes
#   ✓ 2021-03-17 | Return: 0.62% | Reversal: Yes
#   ✓ 2021-04-28 | Return: -0.05% | Reversal: Yes
#   ✓ 2021-06-16 | Return: -0.59% | Reversal: Yes
#   ✓ 2021-07-28 | Return: -0.05% | Reversal: Yes
#   ✓ 2021-09-22 | Return: 0.65% | Reversal: No
#   ✓ 2021-11-03 | Return: 0.65% | Reversal: No
#   ✓ 2021-12-15 | Return: 1.58% | Reversal: Yes
#   ✓ 2022-01-26 | Return: -1.33% | Reversal: No
#   ✓ 2022-03-16 | Return: 1.63% | Reversal: No
#   ✓ 2022-05-04 | Return: 2.85% | Reversal: Yes
#   ✓ 2022-06-15 | Return: 0.69% | Reversal: Yes
#   ✓ 2022-07-27 | Return: 1.83% | Reversal: No
#   ✓ 2022-09-21 | Return: -2.10% | Reversal: No
#   ✓ 2022-11-02 | Return: -2.42% | Reversal: No
#   ✓ 2022-12-14 | Return: -0.50% | Reversal: No
#   ✓ 2023-02-01 | Return: 1.21% | Reversal: No
#   ✓ 2023-03-22 | Return: -1.63% | Reversal: No
#   ✓ 2023-05-03 | Return: -0.76% | Reversal: No
#   ✓ 2023-06-14 | Return: 0.14% | Reversal: No
#   ✓ 2023-07-26 | Return: 0.17% | Reversal: Yes
#   ✓ 2023-09-20 | Return: -1.14% | Reversal: No
#   ✓ 2023-11-01 | Return: 0.87% | Reversal: No
#   ✓ 2023-12-13 | Return: 1.31% | Reversal: Yes
#   ✓ 2024-01-31 | Return: -1.09% | Reversal: Yes
#   ✓ 2024-03-20 | Return: 0.83% | Reversal: Yes
#   ✓ 2024-05-01 | Return: -0.21% | Reversal: Yes
#   ✓ 2024-06-12 | Return: 0.22% | Reversal: Yes
#   ✓ 2024-07-31 | Return: 0.30% | Reversal: Yes
#   ✓ 2024-09-18 | Return: -0.42% | Reversal: Yes
#   ✓ 2024-11-07 | Return: 0.44% | Reversal: No
#   ✓ 2024-12-18 | Return: -2.90% | Reversal: No
#   ✓ 2025-01-29 | Return: -0.30% | Reversal: Yes
#   ✓ 2025-03-19 | Return: 0.76% | Reversal: No
#   ✓ 2025-05-07 | Return: 0.30% | Reversal: No
#   ✓ 2025-06-18 | Return: -0.12% | Reversal: No
#   ✓ 2025-07-30 | Return: -0.29% | Reversal: No
#   ✓ 2025-09-17 | Return: -0.07% | Reversal: Yes
#   ✓ 2025-10-29 | Return: -0.29% | Reversal: No
#   ✓ 2025-12-10 | Return: 0.78% | Reversal: No
#   ✓ 2026-01-28 | Return: -0.34% | Reversal: No
#   ✓ 2026-03-18 | Return: -1.08% | Reversal: Yes
#
# 90 rows

# %%
# Merge linguistic and market data
df = linguistic_df.merge(market_df, on="date", how="left")

# Drop rows with missing market data
df = df.dropna(subset=["sp500_same_day_return"]).reset_index(drop=True)

# Preview
print(f"Final dataset: {len(df)} rows x {len(df.columns)} columns")
print(f"\nColumns:\n{list(df.columns)}")
print(f"\nReversal breakdown:")
print(df["reversal"].value_counts())
print(f"\nBasic stats:")
print(df.describe())

df.head(10)
# Out:
# Final dataset: 89 rows x 17 columns
#
# Columns:
# ['date', 'fk_grade', 'avg_sentence_length', 'total_words', 'cautious_count', 'definitive_count', 'cautious_ratio', 'jargon_count', 'jargon_freq', 'prepared_sentiment', 'qa_sentiment', 'tone_shift', 'sp500_same_day_return', 'sp500_same_day_abs', 'sp500_next_day_return', 'reversal', 'vix_close']
#
# Reversal breakdown:
# reversal
# 0.0    50
# 1.0    39
# Name: count, dtype: int64
#
# Basic stats:
#         fk_grade  avg_sentence_length   total_words  cautious_count  \
# count  89.000000            89.000000     89.000000       89.000000
# mean    9.868315            16.607978   8509.595506       50.101124
# std     1.384099             2.378464   1247.922398       13.002661
# min     7.960000            13.160000   2347.000000        7.000000
# 25%     8.750000            14.720000   7644.000000       42.000000
# 50%     9.430000            15.990000   8615.000000       51.000000
# 75%    11.030000            18.110000   9366.000000       56.000000
# max    13.780000            23.560000  11611.000000       86.000000
#
#        definitive_count  cautious_ratio  jargon_count  jargon_freq  \
# count         89.000000       89.000000     89.000000    89.000000
# mean          52.595506        1.051921     25.820225     3.064978
# std           16.154593        0.456440     12.933889     1.586193
# min           23.000000        0.241000      2.000000     0.700000
# 25%           40.000000        0.738000     17.000000     1.766000
# 50%           51.000000        0.951000     25.000000     3.088000
# 75%           64.000000        1.220000     34.000000     4.026000
# max           90.000000        2.367000     65.000000     7.687000
#
#        prepared_sentiment  qa_sentiment  tone_shift  sp500_same_day_return  \
# count           89.000000     89.000000   89.000000              89.000000
# mean             0.990873      0.999884   -0.009011               0.038804
# std              0.028001      0.000145    0.028010               1.062287
# min              0.836000      0.999000   -0.164000              -3.006300
# 25%              0.996400      0.999900   -0.003500              -0.488200
# 50%              0.997800      0.999900   -0.002000               0.113500
# 75%              0.999000      1.000000   -0.000900               0.721300
# max              0.999600      1.000000   -0.000400               2.845800
#
#        sp500_same_day_abs  sp500_next_day_return   reversal  vix_close
# count           89.000000              89.000000  89.000000  89.000000
# mean             0.808865              -0.119384   0.438202  18.484831
# std              0.684309               1.048935   0.498978   6.016055
# min              0.044800              -3.887600   0.000000   9.780000
# 25%              0.257100              -0.630500   0.000000  14.330000
# 50%              0.646100               0.031300   0.000000  16.820000
# 75%              1.159600               0.447400   1.000000  21.140000
# max              3.006300               2.770100   1.000000  37.210000
#          date  fk_grade  avg_sentence_length  total_words  cautious_count  \
# 0  2011-04-27     11.60                18.57         8681              35
# 1  2011-06-22     10.94                18.11         7306              51
# 2  2011-11-02     11.48                17.87         7402              33
# 3  2012-01-25     13.78                23.56        10066              53
# 4  2012-04-25     11.55                18.93         7644              45
# 5  2012-06-20     10.85                17.61         7239              51
# 6  2012-12-12     12.25                20.77        11611              75
# 7  2013-03-20     10.43                17.21         8906              56
# 8  2013-06-19     11.07                19.01         9414              46
# 9  2013-09-18     12.06                20.35         9014              54
#
#    definitive_count  cautious_ratio  jargon_count  jargon_freq  \
# 0                60           0.583            28        3.225
# 1                31           1.645             7        0.958
# 2                44           0.750             8        1.081
# 3                53           1.000            23        2.285
# 4                35           1.286            28        3.663
# 5                24           2.125            10        1.381
# 6                81           0.926            39        3.359
# 7                40           1.400            28        3.144
# 8                48           0.958            32        3.399
# 9                54           1.000            43        4.770
#
#    prepared_sentiment  qa_sentiment  tone_shift  sp500_same_day_return  \
# 0              0.8860        1.0000     -0.1140                 0.5362
# 1              0.8360        0.9999     -0.1639                -0.6438
# 2              0.9929        0.9999     -0.0070                 1.4988
# 3              0.8360        1.0000     -0.1640                 0.8871
# 4              0.9465        0.9999     -0.0534                 1.3541
# 5              0.9579        0.9999     -0.0420                -0.1731
# 6              0.9954        1.0000     -0.0046                 0.0448
# 7              0.9985        0.9998     -0.0013                 0.6697
# 8              0.9996        1.0000     -0.0004                -1.3863
# 9              0.9988        1.0000     -0.0012                 1.1596
#
#    sp500_same_day_abs  sp500_next_day_return  reversal  vix_close
# 0              0.5362                 0.4890       0.0      15.35
# 1              0.6438                -0.2409       0.0      18.52
# 2              1.4988                 1.8494       0.0      32.74
# 3              0.8871                -0.5919       1.0      18.31
# 4              1.3541                 0.6716       0.0      16.82
# 5              0.1731                -2.2074       0.0      17.24
# 6              0.0448                -0.6321       1.0      15.95
# 7              0.6697                -0.8282       1.0      12.67
# 8              1.3863                -2.2424       0.0      16.64
# 9              1.1596                -0.2895       1.0      13.59

# %%
df.to_csv("fed_presser_dataset.csv", index=False)
from google.colab import files
files.download("fed_presser_dataset.csv")

# %%
# FIX 1: Better sentiment scoring - sentence level averaging
def sentence_sentiment(text):
    if not text:
        return 0
    sentences = re.split(r'[.!?]+', text)
    sentences = [s.strip() for s in sentences if len(s.strip()) > 10]
    if not sentences:
        return 0
    scores = [analyzer.polarity_scores(s)["compound"] for s in sentences]
    return round(np.mean(scores), 4)

# FIX 2: Add Chair identifier
def get_chair(date_str):
    dt = datetime.strptime(date_str, "%Y-%m-%d")
    if dt < datetime(2014, 2, 3):
        return "Bernanke"
    elif dt < datetime(2018, 2, 5):
        return "Yellen"
    else:
        return "Powell"

# FIX 3: Expanded word lists
cautious_words_v2 = [
    "may", "might", "could", "possibly", "perhaps", "uncertain",
    "somewhat", "broadly", "roughly", "approximately", "monitor",
    "watching", "depends", "evaluate", "assess", "gradual",
    "cautious", "patient", "tentative", "moderate", "evolving",
    "unclear", "we'll see", "data dependent", "on the table",
    "range of outcomes", "both sides", "balanced", "measured",
    "some", "fairly", "reasonably", "appears", "seems",
    "suggest", "indicate", "not yet", "premature"
]

definitive_words_v2 = [
    "will", "committed", "confident", "clearly", "strongly",
    "determined", "certain", "absolutely", "must", "decisive",
    "without question", "no doubt", "firmly", "fully",
    "unequivocally", "precisely", "exactly", "certainly",
    "indeed", "necessary", "essential", "critical",
    "significant", "substantial", "robust", "solid",
    "convinced", "unwavering", "resolute"
]

# Rebuild features with fixes
rows_v2 = []
for date_str, data in split_data.items():
    full = data["prepared"] + " " + data["qa"]
    prepared = data["prepared"]
    qa = data["qa"]

    total_words = len(full.split())

    # Updated word counts
    cautious_count = count_words(full, cautious_words_v2)
    definitive_count = count_words(full, definitive_words_v2)
    jargon_count = count_words(full, jargon_words)

    cautious_ratio = round(cautious_count / max(definitive_count, 1), 3)
    jargon_freq = round(jargon_count / max(total_words, 1) * 1000, 3)

    fk_grade = flesch_kincaid_grade(full)
    sent_length = avg_sentence_length(full)

    # Fixed sentiment - sentence level
    prep_sent = sentence_sentiment(prepared)
    qa_sent = sentence_sentiment(qa)
    tone_shift = round(prep_sent - qa_sent, 4)

    date_fmt = datetime.strptime(date_str, "%Y%m%d").strftime("%Y-%m-%d")

    rows_v2.append({
        "date": date_fmt,
        "chair": get_chair(date_fmt),
        "fk_grade": round(fk_grade, 2),
        "avg_sentence_length": round(sent_length, 2),
        "total_words": total_words,
        "cautious_count": cautious_count,
        "definitive_count": definitive_count,
        "cautious_ratio": cautious_ratio,
        "jargon_count": jargon_count,
        "jargon_freq": jargon_freq,
        "prepared_sentiment": prep_sent,
        "qa_sentiment": qa_sent,
        "tone_shift": tone_shift,
    })

linguistic_df_v2 = pd.DataFrame(rows_v2).sort_values("date").reset_index(drop=True)

# Merge with market data
df_v2 = linguistic_df_v2.merge(market_df, on="date", how="left")
df_v2 = df_v2.dropna(subset=["sp500_same_day_return"]).reset_index(drop=True)

print(f"Final dataset: {len(df_v2)} rows x {len(df_v2.columns)} columns")
print(f"\nChair breakdown:")
print(df_v2["chair"].value_counts())
print(f"\nSentiment range check (should NOT all be near 1.0 now):")
print(f"  Prepared sentiment: {df_v2['prepared_sentiment'].min():.4f} to {df_v2['prepared_sentiment'].max():.4f}")
print(f"  Q&A sentiment: {df_v2['qa_sentiment'].min():.4f} to {df_v2['qa_sentiment'].max():.4f}")
print(f"  Tone shift: {df_v2['tone_shift'].min():.4f} to {df_v2['tone_shift'].max():.4f}")

df_v2.head(10)
# Out:
# Final dataset: 89 rows x 18 columns
#
# Chair breakdown:
# chair
# Powell      62
# Yellen      16
# Bernanke    11
# Name: count, dtype: int64
#
# Sentiment range check (should NOT all be near 1.0 now):
#   Prepared sentiment: 0.0214 to 0.2956
#   Q&A sentiment: 0.0237 to 0.1824
#   Tone shift: -0.0938 to 0.2066
#          date     chair  fk_grade  avg_sentence_length  total_words  \
# 0  2011-04-27  Bernanke     11.60                18.57         8681
# 1  2011-06-22  Bernanke     10.94                18.11         7306
# 2  2011-11-02  Bernanke     11.48                17.87         7402
# 3  2012-01-25  Bernanke     13.78                23.56        10066
# 4  2012-04-25  Bernanke     11.55                18.93         7644
# 5  2012-06-20  Bernanke     10.85                17.61         7239
# 6  2012-12-12  Bernanke     12.25                20.77        11611
# 7  2013-03-20  Bernanke     10.43                17.21         8906
# 8  2013-06-19  Bernanke     11.07                19.01         9414
# 9  2013-09-18  Bernanke     12.06                20.35         9014
#
#    cautious_count  definitive_count  cautious_ratio  jargon_count  \
# 0              78                92           0.848            28
# 1              87                49           1.776             7
# 2              69                58           1.190             8
# 3             112                87           1.287            23
# 4              96                57           1.684            28
# 5              87                44           1.977            10
# 6             125               119           1.050            39
# 7             113                63           1.794            28
# 8             113                73           1.548            32
# 9             100                80           1.250            43
#
#    jargon_freq  prepared_sentiment  qa_sentiment  tone_shift  \
# 0        3.225              0.2521        0.1331      0.1190
# 1        0.958              0.2337        0.0765      0.1572
# 2        1.081              0.1036        0.1149     -0.0113
# 3        2.285              0.1947        0.1824      0.0123
# 4        3.663              0.0214        0.1152     -0.0938
# 5        1.381              0.1038        0.1139     -0.0101
# 6        3.359              0.1228        0.1234     -0.0006
# 7        3.144              0.1800        0.0583      0.1217
# 8        3.399              0.2329        0.1384      0.0945
# 9        4.770              0.1967        0.1605      0.0362
#
#    sp500_same_day_return  sp500_same_day_abs  sp500_next_day_return  reversal  \
# 0                 0.5362              0.5362                 0.4890       0.0
# 1                -0.6438              0.6438                -0.2409       0.0
# 2                 1.4988              1.4988                 1.8494       0.0
# 3                 0.8871              0.8871                -0.5919       1.0
# 4                 1.3541              1.3541                 0.6716       0.0
# 5                -0.1731              0.1731                -2.2074       0.0
# 6                 0.0448              0.0448                -0.6321       1.0
# 7                 0.6697              0.6697                -0.8282       1.0
# 8                -1.3863              1.3863                -2.2424       0.0
# 9                 1.1596              1.1596                -0.2895       1.0
#
#    vix_close
# 0      15.35
# 1      18.52
# 2      32.74
# 3      18.31
# 4      16.82
# 5      17.24
# 6      15.95
# 7      12.67
# 8      16.64
# 9      13.59

# %%
df_v2.to_csv("fed_presser_dataset_v2.csv", index=False)
from google.colab import files
files.download("fed_presser_dataset_v2.csv")

# %%
import pandas as pd
import numpy as np
from scipy import stats
import statsmodels.api as sm

df = pd.read_csv("fed_presser_dataset_v2.csv")

# MAIN HYPOTHESIS: complexity -> same-day movement
X = sm.add_constant(df[["fk_grade", "avg_sentence_length", "jargon_freq"]])
y = df["sp500_same_day_abs"]
model_main = sm.OLS(y, X).fit()
print("MAIN HYPOTHESIS")
print(model_main.summary())

# SUPPORTING H1: cautious ratio -> reversal
X1 = sm.add_constant(df[["cautious_ratio"]])
model_h1 = sm.Logit(df["reversal"], X1).fit()
print("\nSUPPORTING H1")
print(model_h1.summary())

# SUPPORTING H2: tone shift t-test
median_shift = df["tone_shift"].median()
high = df[df["tone_shift"] >= median_shift]["sp500_same_day_abs"]
low = df[df["tone_shift"] < median_shift]["sp500_same_day_abs"]
t_stat, p_h2 = stats.ttest_ind(high, low)
print("\nSUPPORTING H2")
print(f"High shift mean: {high.mean():.4f}, Low shift mean: {low.mean():.4f}")
print(f"t-stat: {t_stat:.4f}, p-value: {p_h2:.4f}")

# SUPPORTING H3: complexity x VIX interaction
X3 = df[["fk_grade", "vix_close"]].copy()
X3["fk_x_vix"] = X3["fk_grade"] * X3["vix_close"]
X3 = sm.add_constant(X3)
model_h3 = sm.OLS(df["sp500_same_day_abs"], X3).fit()
print("\nSUPPORTING H3")
print(model_h3.summary())
# Out:
# MAIN HYPOTHESIS
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     sp500_same_day_abs   R-squared:                       0.025
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                    0.7171
# Date:                Mon, 13 Jul 2026   Prob (F-statistic):              0.544
# Time:                        16:02:23   Log-Likelihood:                -90.909
# No. Observations:                  89   AIC:                             189.8
# Df Residuals:                      85   BIC:                             199.8
# Df Model:                           3
# Covariance Type:            nonrobust
# =======================================================================================
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                   1.3780      0.541      2.546      0.013       0.302       2.454
# fk_grade                0.1880      0.241      0.781      0.437      -0.290       0.666
# avg_sentence_length    -0.1485      0.141     -1.053      0.295      -0.429       0.132
# jargon_freq             0.0136      0.053      0.257      0.798      -0.091       0.118
# ==============================================================================
# Omnibus:                       21.185   Durbin-Watson:                   1.678
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               26.859
# Skew:                           1.208   Prob(JB):                     1.47e-06
# Kurtosis:                       4.187   Cond. No.                         148.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Optimization terminated successfully.
#          Current function value: 0.682938
#          Iterations 4
#
# SUPPORTING H1
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               reversal   No. Observations:                   89
# Model:                          Logit   Df Residuals:                       87
# Method:                           MLE   Df Model:                            1
# Date:                Mon, 13 Jul 2026   Pseudo R-squ.:                0.003722
# Time:                        16:02:23   Log-Likelihood:                -60.782
# converged:                       True   LL-Null:                       -61.009
# Covariance Type:            nonrobust   LLR p-value:                    0.5004
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.2171      0.724      0.300      0.764      -1.202       1.637
# cautious_ratio    -0.3628      0.541     -0.671      0.502      -1.423       0.697
# ==================================================================================
#
# SUPPORTING H2
# High shift mean: 0.8423, Low shift mean: 0.7747
# t-stat: 0.4642, p-value: 0.6437
#
# SUPPORTING H3
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:     sp500_same_day_abs   R-squared:                       0.355
# Model:                            OLS   Adj. R-squared:                  0.332
# Method:                 Least Squares   F-statistic:                     15.60
# Date:                Mon, 13 Jul 2026   Prob (F-statistic):           3.61e-08
# Time:                        16:02:23   Log-Likelihood:                -72.499
# No. Observations:                  89   AIC:                             153.0
# Df Residuals:                      85   BIC:                             163.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -3.4746      1.552     -2.239      0.028      -6.560      -0.390
# fk_grade       0.3118      0.155      2.008      0.048       0.003       0.620
# vix_close      0.2347      0.087      2.691      0.009       0.061       0.408
# fk_x_vix      -0.0174      0.009     -1.947      0.055      -0.035       0.000
# ==============================================================================
# Omnibus:                        4.315   Durbin-Watson:                   1.816
# Prob(Omnibus):                  0.116   Jarque-Bera (JB):                4.330
# Skew:                           0.522   Prob(JB):                        0.115
# Kurtosis:                       2.723   Cond. No.                     5.01e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.01e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
